# %% [markdown]
# ![Databricks Academy](https://files.training.databricks.com/binder/prod_main/automated-deployment-with-declarative-automation-bundles-en_us-2.4.0/images/20260828T161450Z/Automated Deployment with Declarative Automation Bundles/Includes/images/common/db-academy.png)

# %% [markdown]
# # Lecture - Variable Substitutions in DABs
#
# ## Overview
#
# In this lecture, you will learn how variables make Declarative Automation Bundles dynamic and reusable. You will review the built-in substitutions Databricks provides, then learn to define simple, complex, and lookup variables, override variable values per target environment, and understand the benefits of using variables.
#
# ## Learning Objectives
#
# By the end of this lecture, you will be able to:
# 1. **Use** the default variable substitutions available in a bundle.
# 2. **Define** simple custom variables, complex variables, and lookup variables.
# 3. **Override** variable values for a specific target environment.
# 4. **Explain** the benefits of using variables in DABs.

# %% [markdown]
# ## A. Variables Overview

# %% [markdown]
# ### A1. Default Substitutions, Simple, and Complex Variables
#
# Declarative Automation Bundles support **substitutions** and **custom variables**, both of which allow values to be resolved dynamically when the bundle is deployed and run. Reference any of them with `${...}`.
# <div style="display:grid;grid-template-columns:1fr 1fr 1fr;gap:18px;max-width:1150px;margin:0 auto;font-family:sans-serif;align-items:start;">
#   <div>
#     <div style="font-size:15pt;font-weight:700;color:#0b2026;border-bottom:3px solid #FF5F46;padding-bottom:6px;margin-bottom:12px;">Default Substitutions</div>
#     <div style="font-size:12.5pt;color:#0b2026;margin-bottom:10px;">By default there are a variety of <b>variable substitutions</b> available:</div>
#     <div style="background:#F9F7F4;border-left:5px solid #FF5F46;border-radius:0 6px 6px 0;padding:7px 12px;font-size:12.5pt;color:#0b2026;font-family:Consolas,Monaco,monospace;box-shadow:0 2px 8px rgba(27,49,57,0.06);margin-bottom:8px;">${bundle.name}</div><div style="background:#F9F7F4;border-left:5px solid #FF5F46;border-radius:0 6px 6px 0;padding:7px 12px;font-size:12.5pt;color:#0b2026;font-family:Consolas,Monaco,monospace;box-shadow:0 2px 8px rgba(27,49,57,0.06);margin-bottom:8px;">${bundle.target}</div><div style="background:#F9F7F4;border-left:5px solid #FF5F46;border-radius:0 6px 6px 0;padding:7px 12px;font-size:12.5pt;color:#0b2026;font-family:Consolas,Monaco,monospace;box-shadow:0 2px 8px rgba(27,49,57,0.06);margin-bottom:8px;">${workspace.file_path}</div><div style="background:#F9F7F4;border-left:5px solid #FF5F46;border-radius:0 6px 6px 0;padding:7px 12px;font-size:12.5pt;color:#0b2026;font-family:Consolas,Monaco,monospace;box-shadow:0 2px 8px rgba(27,49,57,0.06);margin-bottom:8px;">${workspace.root_path}</div><div style="background:#F9F7F4;border-left:5px solid #FF5F46;border-radius:0 6px 6px 0;padding:7px 12px;font-size:12.5pt;color:#0b2026;font-family:Consolas,Monaco,monospace;box-shadow:0 2px 8px rgba(27,49,57,0.06);margin-bottom:8px;">${resources.jobs.&lt;job-name&gt;.id}</div><div style="background:#F9F7F4;border-left:5px solid #FF5F46;border-radius:0 6px 6px 0;padding:7px 12px;font-size:12.5pt;color:#0b2026;font-family:Consolas,Monaco,monospace;box-shadow:0 2px 8px rgba(27,49,57,0.06);margin-bottom:8px;">${resources.models.&lt;model-name&gt;.name}</div><div style="background:#F9F7F4;border-left:5px solid #FF5F46;border-radius:0 6px 6px 0;padding:7px 12px;font-size:12.5pt;color:#0b2026;font-family:Consolas,Monaco,monospace;box-shadow:0 2px 8px rgba(27,49,57,0.06);margin-bottom:8px;">${resources.pipelines.&lt;pipeline-name&gt;.name}</div>
#   </div>
#   <div>
#     <div style="font-size:15pt;font-weight:700;color:#0b2026;border-bottom:3px solid #4299E0;padding-bottom:6px;margin-bottom:12px;">Simple Custom Variables</div>
#     <ul style="font-size:12.5pt;color:#0b2026;padding-left:18px;margin:0 0 10px 0;line-height:1.45;">
#       <li>You can define <b>simple custom variables</b> in your bundle to enable dynamic retrieval of values needed for many scenarios.</li>
#       <li>Custom variables are declared in your bundle configuration files within the <b>variables</b> mapping.</li>
#     </ul>
#     <div class="code-block" data-language="yaml">
# variables:
#   my_lab_user_name:
#     description: Your user name
#     default: labuser23904
# </div>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/prism/1.29.0/themes/prism.min.css" rel="stylesheet" />
# <script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.29.0/prism.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.29.0/components/prism-yaml.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.29.0/components/prism-bash.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.29.0/components/prism-python.min.js"></script>
# <script>
# (function() {
#   document.querySelectorAll('.code-block').forEach(function(block) {
#     if (block.getAttribute('data-processed')) return;
#     block.setAttribute('data-processed','true');
#     var lang=block.getAttribute('data-language')||'yaml'; var c=block.textContent.trim();
#     var id='c-'+Math.random().toString(36).substr(2,9);
#     block.innerHTML='<div style="position:relative;margin:12px 0;"><button class="copy-btn" style="position:absolute;top:8px;right:8px;padding:4px 12px;font-size:12px;background:#ddd;color:#333;border:1px solid #ccc;border-radius:4px;cursor:pointer;z-index:10;">Copy</button><pre style="background:#f8f8f8;border-radius:8px;padding:16px;padding-top:40px;overflow-x:auto;margin:0;border:1px solid #e0e0e0;"><code id="'+id+'" class="language-'+lang+'" style="font-family:Consolas,Monaco,monospace;font-size:14px;"></code></pre></div>';
#     var ce=document.getElementById(id); ce.textContent=c; Prism.highlightElement(ce);
#     block.querySelector('.copy-btn').onclick=function(){var t=document.createElement('textarea');t.value=c;document.body.appendChild(t);t.select();document.execCommand('copy');document.body.removeChild(t);this.textContent='✓ Copied!';setTimeout(()=>this.textContent='Copy',2000);};
#   });
# })();
# </script>
#   </div>
#   <div>
#     <div style="font-size:15pt;font-weight:700;color:#0b2026;border-bottom:3px solid #00A972;padding-bottom:6px;margin-bottom:12px;">Complex Variables</div>
#     <ul style="font-size:12.5pt;color:#0b2026;padding-left:18px;margin:0 0 10px 0;line-height:1.45;">
#       <li>A custom variable is assumed to be of type <b>string</b> unless you define it as a complex variable.</li>
#       <li>Define a custom variable by setting the <b>type</b> to <code>complex</code>.</li>
#     </ul>
#     <div class="code-block" data-language="yaml">
# variables:
#   my_cluster:
#     description: "My cluster"
#     type: complex
#     default:
#       spark_version: "15.4.x-scala2.11"
#       node_type_id: "Standard_DS3_v2"
#       num_workers: 2
# </div>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/prism/1.29.0/themes/prism.min.css" rel="stylesheet" />
# <script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.29.0/prism.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.29.0/components/prism-yaml.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.29.0/components/prism-bash.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.29.0/components/prism-python.min.js"></script>
# <script>
# (function() {
#   document.querySelectorAll('.code-block').forEach(function(block) {
#     if (block.getAttribute('data-processed')) return;
#     block.setAttribute('data-processed','true');
#     var lang=block.getAttribute('data-language')||'yaml'; var c=block.textContent.trim();
#     var id='c-'+Math.random().toString(36).substr(2,9);
#     block.innerHTML='<div style="position:relative;margin:12px 0;"><button class="copy-btn" style="position:absolute;top:8px;right:8px;padding:4px 12px;font-size:12px;background:#ddd;color:#333;border:1px solid #ccc;border-radius:4px;cursor:pointer;z-index:10;">Copy</button><pre style="background:#f8f8f8;border-radius:8px;padding:16px;padding-top:40px;overflow-x:auto;margin:0;border:1px solid #e0e0e0;"><code id="'+id+'" class="language-'+lang+'" style="font-family:Consolas,Monaco,monospace;font-size:14px;"></code></pre></div>';
#     var ce=document.getElementById(id); ce.textContent=c; Prism.highlightElement(ce);
#     block.querySelector('.copy-btn').onclick=function(){var t=document.createElement('textarea');t.value=c;document.body.appendChild(t);t.select();document.execCommand('copy');document.body.removeChild(t);this.textContent='✓ Copied!';setTimeout(()=>this.textContent='Copy',2000);};
#   });
# })();
# </script>
#   </div>
# </div>
#
# ##### Additional notes
#
# <details>
#
# - Declarative Automation Bundles support substitutions and custom variables, making bundle configuration files more modular and reusable. Both allow dynamic retrieval of values, so settings can be determined when the bundle is deployed and run.
# - To use a variable in a YAML file, reference it with a dollar sign, curly braces, and the mapping followed by the variable name.
# - Common default substitutions include `${{bundle.target}}` for the target environment, `${{workspace.file_path}}` for the workspace file path, and `${{resources.jobs.<job-name>.id}}`, among others.
# - Custom variables are declared under the top-level `variables` mapping. A simple custom variable is assumed to be of type string; for more structured data, set `type: complex`.
# - The complex example `my_cluster` defines a default with a Spark version, node type, and number of workers.
#
# </details>

# %% [markdown]
# ## B. Defining Custom Variables

# %% [markdown]
# ### B1. Creating and Referencing Simple Custom Variables
#
# The bundle settings file can contain one top-level `variables` mapping. Variables can reference other variables with `${var.name}` &mdash; here `catalog_dev` and `catalog_prod` build on `my_lab_user_name`.
#
#
# <style>
# .b1wrap { display:grid; grid-template-columns:minmax(240px, 0.9fr) minmax(0, 1.1fr); gap:18px; max-width:1150px; margin:0 auto; font-family:sans-serif; align-items:start; }
# .b1left { display:flex; flex-direction:column; gap:10px; min-width:0; }
# .b1card { background:#F9F7F4; border-radius:8px; padding:11px 14px; cursor:pointer; border-left:6px solid var(--cc); box-shadow:0 2px 8px rgba(27,49,57,0.06); transition:transform .1s; user-select:none; }
# .b1card:hover { transform:translateX(3px); }
# .b1card.active { background:#fff; outline:2px solid var(--cc); }
# .b1lbl { font-weight:700; font-size:13.5pt; color:var(--cc); }
# .b1sub { font-size:12.5pt; color:#0b2026; margin-top:3px; line-height:1.4; }
# .b1right { min-width:0; }
# .b1pre { background:#f8f8f8; border:1px solid #e0e0e0; border-radius:8px; padding:14px 16px; margin:0; overflow-x:auto; font-family:Consolas,Monaco,monospace; font-size:12pt; line-height:1.5; color:#1B3139; }
# .b1ln { display:block; white-space:pre; padding:0 6px; border-radius:3px; transition:background .15s; }
# .b1hint { font-size:12pt;color:#5E7077;font-style:italic;margin-bottom:8px; }
# @media (max-width:780px){ .b1wrap{ grid-template-columns:1fr; } }
# </style><div class="b1wrap"><div class="b1left"><div class="b1hint">Click an item to highlight it in the code &rarr;</div><div class="b1card" data-lines="1" data-idx="0" style="--cc:#98102A;" onclick="b1sel(0)"><div class="b1lbl">variables mapping</div><div class="b1sub">The bundle settings file can contain one top-level <b>variables</b> mapping where custom variables are defined.</div></div><div class="b1card" data-lines="2,3,4" data-idx="1" style="--cc:#4299E0;" onclick="b1sel(1)"><div class="b1lbl">Create a variable</div><div class="b1sub">Create a variable named <code>my_lab_user_name</code> with the default value of <i>labuser23904</i>.</div></div><div class="b1card" data-lines="6,7,8,10,11,12" data-idx="2" style="--cc:#00A972;" onclick="b1sel(2)"><div class="b1lbl">Reference a variable</div><div class="b1sub"><code>catalog_dev</code> and <code>catalog_prod</code> use the <code>my_lab_user_name</code> value and append strings.</div></div></div><div class="b1right"><div style="font-size:12pt;color:#5E7077;font-style:italic;margin-bottom:6px;">databricks.yml</div><pre class="b1pre"><span class="b1ln" data-ln="0">...</span><span class="b1ln" data-ln="1">variables:</span><span class="b1ln" data-ln="2">  my_lab_user_name:</span><span class="b1ln" data-ln="3">    description: Your user name</span><span class="b1ln" data-ln="4">    default: labuser23904</span><span class="b1ln" data-ln="5"> </span><span class="b1ln" data-ln="6">  catalog_dev:</span><span class="b1ln" data-ln="7">    description: Development catalog reference</span><span class="b1ln" data-ln="8">    default: ${var.my_lab_user_name}_1_dev</span><span class="b1ln" data-ln="9"> </span><span class="b1ln" data-ln="10">  catalog_prod:</span><span class="b1ln" data-ln="11">    description: Production catalog reference</span><span class="b1ln" data-ln="12">    default: ${var.my_lab_user_name}_3_prod</span><span class="b1ln" data-ln="13">...</span></pre></div></div>
# <script>
# (function(){
#   var COLORS=['rgba(152,16,42,0.22)', 'rgba(66,153,224,0.22)', 'rgba(0,169,114,0.22)'];
#   window.b1sel=function(idx){
#     document.querySelectorAll('.b1ln').forEach(function(s){ s.style.background=''; });
#     document.querySelectorAll('.b1card').forEach(function(c){ c.classList.remove('active'); });
#     var card=document.querySelector('.b1card[data-idx="'+idx+'"]'); if(!card) return; card.classList.add('active');
#     card.getAttribute('data-lines').split(',').forEach(function(n){ var s=document.querySelector('.b1ln[data-ln="'+n+'"]'); if(s) s.style.background=COLORS[idx]; });
#   };
#   window.addEventListener('load',function(){ window.b1sel(0); });
# })();
# </script>
#
# <div style="max-width:1150px;margin:14px auto 0 auto;font-family:sans-serif;display:flex;gap:14px;flex-wrap:wrap;">
#   <div style="background:rgba(255,95,70,0.10);border-radius:6px;padding:10px 16px;font-family:Consolas,Monaco,monospace;font-size:13pt;color:#0b2026;"><b>catalog_dev</b> = labuser23904_1_dev</div>
#   <div style="background:rgba(255,95,70,0.10);border-radius:6px;padding:10px 16px;font-family:Consolas,Monaco,monospace;font-size:13pt;color:#0b2026;"><b>catalog_prod</b> = labuser23904_3_prod</div>
# </div>
#
# ##### Additional notes
#
# <details>
#
# - Define the `variables` top-level mapping, then add custom variables beneath it. The bundle settings file can contain only one top-level `variables` mapping.
# - Create a variable named `my_lab_user_name` with a default value of `labuser23904`.
# - Reference a custom variable using `var` followed by a dot and the variable name in curly braces, then append literal text. Here `my_lab_user_name` is reused to build `catalog_dev` and `catalog_prod` by appending `_1_dev` and `_3_prod`.
# - As a result, `catalog_dev` resolves to `labuser23904_1_dev` and `catalog_prod` resolves to `labuser23904_3_prod`.
# - This technique lets you reference or override variables throughout the `databricks.yml` file.
#
# </details>

# %% [markdown]
# ### B2. Defining a Complex Variable
#
# A variable is assumed to be of type string unless you define it as a complex variable by setting `type: complex`. This lets a single variable carry structured data.
#
#
# <style>
# .b2wrap { display:grid; grid-template-columns:minmax(240px, 0.9fr) minmax(0, 1.1fr); gap:18px; max-width:1150px; margin:0 auto; font-family:sans-serif; align-items:start; }
# .b2left { display:flex; flex-direction:column; gap:10px; min-width:0; }
# .b2card { background:#F9F7F4; border-radius:8px; padding:11px 14px; cursor:pointer; border-left:6px solid var(--cc); box-shadow:0 2px 8px rgba(27,49,57,0.06); transition:transform .1s; user-select:none; }
# .b2card:hover { transform:translateX(3px); }
# .b2card.active { background:#fff; outline:2px solid var(--cc); }
# .b2lbl { font-weight:700; font-size:13.5pt; color:var(--cc); }
# .b2sub { font-size:12.5pt; color:#0b2026; margin-top:3px; line-height:1.4; }
# .b2right { min-width:0; }
# .b2pre { background:#f8f8f8; border:1px solid #e0e0e0; border-radius:8px; padding:14px 16px; margin:0; overflow-x:auto; font-family:Consolas,Monaco,monospace; font-size:12pt; line-height:1.5; color:#1B3139; }
# .b2ln { display:block; white-space:pre; padding:0 6px; border-radius:3px; transition:background .15s; }
# .b2hint { font-size:12pt;color:#5E7077;font-style:italic;margin-bottom:8px; }
# @media (max-width:780px){ .b2wrap{ grid-template-columns:1fr; } }
# </style><div class="b2wrap"><div class="b2left"><div class="b2hint">Click an item to highlight it in the code &rarr;</div><div class="b2card" data-lines="4,5,6,7,8,9,10" data-idx="0" style="--cc:#00A972;" onclick="b2sel(0)"><div class="b2lbl">type: complex</div><div class="b2sub">A variable is assumed to be of type <b>string</b> unless you define it as a <b>complex</b> variable.</div></div></div><div class="b2right"><div style="font-size:12pt;color:#5E7077;font-style:italic;margin-bottom:6px;">databricks.yml</div><pre class="b2pre"><span class="b2ln" data-ln="0">bundle:</span><span class="b2ln" data-ln="1">  name: demo08_bundle</span><span class="b2ln" data-ln="2">...</span><span class="b2ln" data-ln="3">variables:</span><span class="b2ln" data-ln="4">  my_cluster:</span><span class="b2ln" data-ln="5">    description: &quot;My cluster&quot;</span><span class="b2ln" data-ln="6">    type: complex</span><span class="b2ln" data-ln="7">    default:</span><span class="b2ln" data-ln="8">      spark_version: &quot;15.4.x-scala2.11&quot;</span><span class="b2ln" data-ln="9">      node_type_id: &quot;Standard_DS3_v2&quot;</span><span class="b2ln" data-ln="10">      num_workers: 2</span><span class="b2ln" data-ln="11">...</span></pre></div></div>
# <script>
# (function(){
#   var COLORS=['rgba(0,169,114,0.22)'];
#   window.b2sel=function(idx){
#     document.querySelectorAll('.b2ln').forEach(function(s){ s.style.background=''; });
#     document.querySelectorAll('.b2card').forEach(function(c){ c.classList.remove('active'); });
#     var card=document.querySelector('.b2card[data-idx="'+idx+'"]'); if(!card) return; card.classList.add('active');
#     card.getAttribute('data-lines').split(',').forEach(function(n){ var s=document.querySelector('.b2ln[data-ln="'+n+'"]'); if(s) s.style.background=COLORS[idx]; });
#   };
#   window.addEventListener('load',function(){ window.b2sel(0); });
# })();
# </script>
#
# ##### Additional notes
#
# <details>
#
# - By default a variable is assumed to be of type string unless defined as a complex variable.
# - The `my_cluster` variable is defined as `type: complex` with a default that specifies a Spark version, node type, and number of workers &mdash; providing structured data in one variable.
#
# </details>

# %% [markdown]
# ### B3. Lookup Variables
#
# For specific object types you can define a **lookup** for a custom variable to retrieve the object's ID dynamically.
#
#
# <style>
# .b3wrap { display:grid; grid-template-columns:minmax(240px, 0.9fr) minmax(0, 1.1fr); gap:18px; max-width:1150px; margin:0 auto; font-family:sans-serif; align-items:start; }
# .b3left { display:flex; flex-direction:column; gap:10px; min-width:0; }
# .b3card { background:#F9F7F4; border-radius:8px; padding:11px 14px; cursor:pointer; border-left:6px solid var(--cc); box-shadow:0 2px 8px rgba(27,49,57,0.06); transition:transform .1s; user-select:none; }
# .b3card:hover { transform:translateX(3px); }
# .b3card.active { background:#fff; outline:2px solid var(--cc); }
# .b3lbl { font-weight:700; font-size:13.5pt; color:var(--cc); }
# .b3sub { font-size:12.5pt; color:#0b2026; margin-top:3px; line-height:1.4; }
# .b3right { min-width:0; }
# .b3pre { background:#f8f8f8; border:1px solid #e0e0e0; border-radius:8px; padding:14px 16px; margin:0; overflow-x:auto; font-family:Consolas,Monaco,monospace; font-size:12pt; line-height:1.5; color:#1B3139; }
# .b3ln { display:block; white-space:pre; padding:0 6px; border-radius:3px; transition:background .15s; }
# .b3hint { font-size:12pt;color:#5E7077;font-style:italic;margin-bottom:8px; }
# @media (max-width:780px){ .b3wrap{ grid-template-columns:1fr; } }
# </style><div class="b3wrap"><div class="b3left"><div class="b3hint">Click an item to highlight it in the code &rarr;</div><div class="b3card" data-lines="2,3" data-idx="0" style="--cc:#4299E0;" onclick="b3sel(0)"><div class="b3lbl">Create the new variable</div><div class="b3sub">Define a new custom variable &mdash; here <code>my_cluster_id</code>.</div></div><div class="b3card" data-lines="4,5" data-idx="1" style="--cc:#00A972;" onclick="b3sel(1)"><div class="b3lbl">Lookup the object</div><div class="b3sub">Use the <b>lookup</b> mapping to resolve the cluster name <code>myclustername</code> to its cluster ID.</div></div></div><div class="b3right"><div style="font-size:12pt;color:#5E7077;font-style:italic;margin-bottom:6px;">databricks.yml</div><pre class="b3pre"><span class="b3ln" data-ln="0">...</span><span class="b3ln" data-ln="1">variables:</span><span class="b3ln" data-ln="2">  my_cluster_id:</span><span class="b3ln" data-ln="3">    description: &quot;Get the cluster ID using a lookup variable&quot;</span><span class="b3ln" data-ln="4">    lookup:</span><span class="b3ln" data-ln="5">      cluster: myclustername</span><span class="b3ln" data-ln="6">...</span></pre></div></div>
# <script>
# (function(){
#   var COLORS=['rgba(66,153,224,0.22)', 'rgba(0,169,114,0.22)'];
#   window.b3sel=function(idx){
#     document.querySelectorAll('.b3ln').forEach(function(s){ s.style.background=''; });
#     document.querySelectorAll('.b3card').forEach(function(c){ c.classList.remove('active'); });
#     var card=document.querySelector('.b3card[data-idx="'+idx+'"]'); if(!card) return; card.classList.add('active');
#     card.getAttribute('data-lines').split(',').forEach(function(n){ var s=document.querySelector('.b3ln[data-ln="'+n+'"]'); if(s) s.style.background=COLORS[idx]; });
#   };
#   window.addEventListener('load',function(){ window.b3sel(0); });
# })();
# </script>
#
# ##### Additional notes
#
# <details>
#
# - For specific object types, define a lookup for a custom variable to retrieve the object's ID.
# - Specify the variable name (`my_cluster_id`), then use the `lookup` mapping to define what to look up &mdash; here the cluster named `myclustername`, whose ID becomes the variable's value.
# - When a lookup is defined, the ID of the object with the specified name is always used as the variable's value, ensuring the correct resolved ID.
#
# </details>

# %% [markdown]
# ### B4. Lookups for a Variety of Environment Configurations
#
# You can define lookups for many object types:
# <div style="display:flex;flex-wrap:wrap;gap:8px;max-width:1000px;margin:0 auto;font-family:sans-serif;"><span style="background:rgba(255,95,70,0.08);border:1px solid #4299E0;border-radius:16px;padding:6px 16px;font-size:13.5pt;color:#0b2026;">alert</span><span style="background:rgba(255,95,70,0.08);border:1px solid #4299E0;border-radius:16px;padding:6px 16px;font-size:13.5pt;color:#0b2026;">cluster_policy</span><span style="background:rgba(255,95,70,0.08);border:1px solid #4299E0;border-radius:16px;padding:6px 16px;font-size:13.5pt;color:#0b2026;">cluster</span><span style="background:rgba(255,95,70,0.08);border:1px solid #4299E0;border-radius:16px;padding:6px 16px;font-size:13.5pt;color:#0b2026;">dashboard</span><span style="background:rgba(255,95,70,0.08);border:1px solid #4299E0;border-radius:16px;padding:6px 16px;font-size:13.5pt;color:#0b2026;">instance_pool</span><span style="background:rgba(255,95,70,0.08);border:1px solid #4299E0;border-radius:16px;padding:6px 16px;font-size:13.5pt;color:#0b2026;">job</span><span style="background:rgba(255,95,70,0.08);border:1px solid #4299E0;border-radius:16px;padding:6px 16px;font-size:13.5pt;color:#0b2026;">metastore</span><span style="background:rgba(255,95,70,0.08);border:1px solid #4299E0;border-radius:16px;padding:6px 16px;font-size:13.5pt;color:#0b2026;">notification_destination</span><span style="background:rgba(255,95,70,0.08);border:1px solid #4299E0;border-radius:16px;padding:6px 16px;font-size:13.5pt;color:#0b2026;">pipeline</span><span style="background:rgba(255,95,70,0.08);border:1px solid #4299E0;border-radius:16px;padding:6px 16px;font-size:13.5pt;color:#0b2026;">query</span><span style="background:rgba(255,95,70,0.08);border:1px solid #4299E0;border-radius:16px;padding:6px 16px;font-size:13.5pt;color:#0b2026;">service_principal</span><span style="background:rgba(255,95,70,0.08);border:1px solid #4299E0;border-radius:16px;padding:6px 16px;font-size:13.5pt;color:#0b2026;">warehouse</span></div>
#
# ##### Additional notes
#
# <details>
#
# - Lookup variables are available for the alert, cluster_policy, cluster, dashboard, instance_pool, job, metastore, notification_destination, pipeline, query, service_principal, and warehouse object types.
#
# </details>

# %% [markdown]
# ## C. Target Environment Overrides

# %% [markdown]
# ### C1. Target Environment Variable Overrides
#
# Use the `targets` mapping to dynamically modify a variable's value in each environment.
#
#
# <style>
# .c1wrap { display:grid; grid-template-columns:minmax(240px, 0.9fr) minmax(0, 1.1fr); gap:18px; max-width:1150px; margin:0 auto; font-family:sans-serif; align-items:start; }
# .c1left { display:flex; flex-direction:column; gap:10px; min-width:0; }
# .c1card { background:#F9F7F4; border-radius:8px; padding:11px 14px; cursor:pointer; border-left:6px solid var(--cc); box-shadow:0 2px 8px rgba(27,49,57,0.06); transition:transform .1s; user-select:none; }
# .c1card:hover { transform:translateX(3px); }
# .c1card.active { background:#fff; outline:2px solid var(--cc); }
# .c1lbl { font-weight:700; font-size:13.5pt; color:var(--cc); }
# .c1sub { font-size:12.5pt; color:#0b2026; margin-top:3px; line-height:1.4; }
# .c1right { min-width:0; }
# .c1pre { background:#f8f8f8; border:1px solid #e0e0e0; border-radius:8px; padding:14px 16px; margin:0; overflow-x:auto; font-family:Consolas,Monaco,monospace; font-size:12pt; line-height:1.5; color:#1B3139; }
# .c1ln { display:block; white-space:pre; padding:0 6px; border-radius:3px; transition:background .15s; }
# .c1hint { font-size:12pt;color:#5E7077;font-style:italic;margin-bottom:8px; }
# @media (max-width:780px){ .c1wrap{ grid-template-columns:1fr; } }
# </style><div class="c1wrap"><div class="c1left"><div class="c1hint">Click an item to highlight it in the code &rarr;</div><div class="c1card" data-lines="1" data-idx="0" style="--cc:#00A972;" onclick="c1sel(0)"><div class="c1lbl">targets mapping</div><div class="c1sub">Dynamically modify variable values within each target environment using the <b>target</b> top-level mapping.</div></div><div class="c1card" data-lines="2,3,4,5" data-idx="1" style="--cc:#4299E0;" onclick="c1sel(1)"><div class="c1lbl">development</div><div class="c1sub">When deploying to <b>development</b>, <code>target_catalog</code> uses the <code>catalog_dev</code> value.</div></div><div class="c1card" data-lines="6,7,8,9" data-idx="2" style="--cc:#98102A;" onclick="c1sel(2)"><div class="c1lbl">production</div><div class="c1sub">When deploying to <b>production</b>, <code>target_catalog</code> uses the <code>catalog_prod</code> value.</div></div></div><div class="c1right"><div style="font-size:12pt;color:#5E7077;font-style:italic;margin-bottom:6px;">databricks.yml</div><pre class="c1pre"><span class="c1ln" data-ln="0">...</span><span class="c1ln" data-ln="1">targets:</span><span class="c1ln" data-ln="2">  development:</span><span class="c1ln" data-ln="3">    ...</span><span class="c1ln" data-ln="4">    variables:</span><span class="c1ln" data-ln="5">      target_catalog: ${var.catalog_dev}</span><span class="c1ln" data-ln="6">  production:</span><span class="c1ln" data-ln="7">    ...</span><span class="c1ln" data-ln="8">    variables:</span><span class="c1ln" data-ln="9">      target_catalog: ${var.catalog_prod}</span></pre></div></div>
# <script>
# (function(){
#   var COLORS=['rgba(0,169,114,0.22)', 'rgba(66,153,224,0.22)', 'rgba(152,16,42,0.22)'];
#   window.c1sel=function(idx){
#     document.querySelectorAll('.c1ln').forEach(function(s){ s.style.background=''; });
#     document.querySelectorAll('.c1card').forEach(function(c){ c.classList.remove('active'); });
#     var card=document.querySelector('.c1card[data-idx="'+idx+'"]'); if(!card) return; card.classList.add('active');
#     card.getAttribute('data-lines').split(',').forEach(function(n){ var s=document.querySelector('.c1ln[data-ln="'+n+'"]'); if(s) s.style.background=COLORS[idx]; });
#   };
#   window.addEventListener('load',function(){ window.c1sel(0); });
# })();
# </script>
#
# <div style="max-width:1150px;margin:14px auto 0 auto;font-family:sans-serif;background:rgba(255,95,70,0.12);border-left:4px solid #FF5F46;border-radius:4px;padding:12px 16px;font-size:13.5pt;color:#0b2026;">
#   A <b>default value</b> for the variable must be defined in the <b>variables</b> top-level mapping in order for an override to work.
# </div>
#
# ##### Additional notes
#
# <details>
#
# - Custom variables can be used throughout the `databricks.yml` file, including within the `targets` mapping, which lets you dynamically modify variable values for each target environment.
# - When deploying to development, `target_catalog` uses the `catalog_dev` value; when deploying to production, it uses the `catalog_prod` value.
# - If no override is specified for a variable, it defaults to its original value.
# - A default value for the variable must be defined in the top-level `variables` mapping for an override to work.
#
# </details>

# %% [markdown]
# ## D. Why Variables Matter

# %% [markdown]
# ### D1. Benefits of Using Variables
#
# <div style="display:grid;grid-template-columns:1fr 1fr 1fr;gap:24px;max-width:1150px;margin:0 auto;font-family:sans-serif;align-items:start;">
#   <div style="text-align:center;padding:0 8px;">
#   <div style="margin-bottom:12px;"><img src="data:image/png;base64,..." alt="Customizable for Different Environments" style="height:64px;vertical-align:middle;"/></div>
#   <div style="font-size:15pt;font-weight:700;color:#0b2026;margin-bottom:8px;line-height:1.25;">Customizable for Different Environments</div>
#   <div style="font-size:13pt;color:#0b2026;line-height:1.45;">Easily modify configurations (e.g., database connections, file paths, etc.) for development, staging, and/or production environments.</div>
# </div>
#   <div style="text-align:center;padding:0 8px;">
#   <div style="margin-bottom:12px;"><img src="data:image/png;base64,..." alt="Reusability Across Databricks Projects" style="height:64px;vertical-align:middle;"/></div>
#   <div style="font-size:15pt;font-weight:700;color:#0b2026;margin-bottom:8px;line-height:1.25;">Reusability Across Databricks Projects</div>
#   <div style="font-size:13pt;color:#0b2026;line-height:1.45;">You can use the same asset bundle across multiple teams or workspaces by adjusting only variable values.</div>
# </div>
#   <div style="text-align:center;padding:0 8px;">
#   <div style="margin-bottom:12px;"><img src="data:image/png;base64,..." alt="Easy Maintenance &amp; Updates" style="height:64px;vertical-align:middle;"/></div>
#   <div style="font-size:15pt;font-weight:700;color:#0b2026;margin-bottom:8px;line-height:1.25;">Easy Maintenance &amp; Updates</div>
#   <div style="font-size:13pt;color:#0b2026;line-height:1.45;">Quickly update assets by modifying variables to ensure consistency and reduce errors.</div>
# </div>
# </div>
#
# ##### Additional notes
#
# <details>
#
# - Variables let you customize configurations &mdash; catalogs, file paths, and other settings &mdash; for development, staging, and production environments.
# - They enable reusability across Databricks projects: the same asset bundle can be used across multiple teams or workspaces by adjusting only the variable values.
# - They make maintenance and updates easy: assets and configurations can be updated quickly, keeping environments consistent and reducing the risk of errors.
#
# </details>

# %% [markdown]
# ## E. Conclusion
#
# - Bundles provide many **default substitutions** you can reference with `${...}`.
# - You can define **simple**, **complex**, and **lookup** custom variables in the `variables` mapping.
# - **Target overrides** give a variable a different value per environment (a default is required).
# - Variables make bundles **reusable, maintainable, and customizable** across environments.
#
# ### Next Steps
#
# In the next demo, you will deploy a DAB to multiple environments using variables and overrides.

# %% [markdown]
# &copy; 2026 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
