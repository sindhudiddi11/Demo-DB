# %% [markdown]
# ![Databricks Academy](https://files.training.databricks.com/binder/prod_main/automated-deployment-with-declarative-automation-bundles-en_us-2.4.0/images/20260828T161450Z/Automated Deployment with Declarative Automation Bundles/Includes/images/common/db-academy.png)

# %% [markdown]
# # Lecture - Developing Locally with Visual Studio Code (VS Code)
#
# ## Overview
#
# In this lecture, you will get a quick introduction to the developer tools that let you work with Databricks locally from VS Code: the Databricks CLI, Databricks Connect V2, and the Databricks VS Code Extension.
#
# ## Learning Objectives
#
# By the end of this lecture, you will be able to:
# 1. **Describe** the three developer tools for working with Databricks from VS Code.
# 2. **Explain** when to use the CLI, Databricks Connect, and the VS Code Extension.

# %% [markdown]
# ## A. Developer Tools for Local Development

# %% [markdown]
# ### A1. Developer Tools Overview
#
# Three tools bring Databricks into local development from VS Code. Each is suited to a different kind of work.
# <div style="display:grid;grid-template-columns:1fr 1fr 1fr;gap:24px;max-width:1150px;margin:0 auto;font-family:sans-serif;align-items:start;">
#   <div style="border-top:4px solid #4299E0;padding-top:14px;">
#   <div style="text-align:center;margin-bottom:10px;height:52px;display:flex;align-items:center;justify-content:center;"><img src="data:image/png;base64,..." alt="terminal" style="height:44px;vertical-align:middle;"/></div>
#   <div style="font-size:15pt;font-weight:700;color:#0b2026;text-align:center;margin-bottom:12px;">Databricks CLI</div>
#   <ul style="font-size:12.5pt;color:#0b2026;padding-left:20px;margin:0;line-height:1.5;"><li>Ideal for <b>shell scripting</b> &amp; lightweight command-line tasks</li><li>Useful in development and CI/CD processes</li><li>Supports unified authentication (OAuth, PATs, etc.)</li><li>More interactive debugging compared to Notebooks</li></ul>
# </div>
#   <div style="border-top:4px solid #00A972;padding-top:14px;">
#   <div style="text-align:center;margin-bottom:10px;height:52px;display:flex;align-items:center;justify-content:center;"><img src="data:image/png;base64,..." alt="databricks" style="height:44px;vertical-align:middle;"/></div>
#   <div style="font-size:15pt;font-weight:700;color:#0b2026;text-align:center;margin-bottom:12px;">Databricks Connect V2</div>
#   <ul style="font-size:12.5pt;color:#0b2026;padding-left:20px;margin:0;line-height:1.5;"><li>Runs Apache Spark code <b>remotely</b> on a Databricks cluster from a local environment</li><li>Ideal for interactive debugging and remote Spark job execution</li><li>Easy setup with <code>pip install databricks-connect&gt;=</code> your version</li></ul>
# </div>
#   <div style="border-top:4px solid #FFAB00;padding-top:14px;">
#   <div style="text-align:center;margin-bottom:10px;height:52px;display:flex;align-items:center;justify-content:center;"><span style="display:inline-flex;align-items:center;gap:6px;"><img src="data:image/png;base64,..." alt="databricks" style="height:44px;vertical-align:middle;"/><svg width="26" height="26" viewBox="0 0 100 100" style="vertical-align:middle;"><path d="M75 8 L95 18 V82 L75 92 L30 55 L12 70 L5 66 V34 L12 30 L30 45 Z M75 30 L48 50 L75 70 Z" fill="#3B82C4"/></svg></span></div>
#   <div style="font-size:15pt;font-weight:700;color:#0b2026;text-align:center;margin-bottom:12px;">Databricks VS Code Extension</div>
#   <ul style="font-size:12.5pt;color:#0b2026;padding-left:20px;margin:0;line-height:1.5;"><li>Integrates Databricks into VS Code for batch and interactive development</li><li>Simplifies setup with resource explorers and Databricks CLI</li><li>Supports running and debugging Python files on Databricks clusters</li><li>Keeps developers within VS Code, and provides <b>DAB features</b></li></ul>
# </div>
# </div>
#
# ##### Additional notes
#
# <details>
#
# - For many developers, an IDE like VS Code is the preferred choice &mdash; you can interact with Databricks in multiple ways while staying in the IDE, avoiding a switch to the Databricks browser UI.
# - The <b>Databricks CLI</b> allows quick interactions through the command line. It is ideal for shell scripting and lightweight command-line tasks, useful in development and CI/CD processes, supports unified authentication (OAuth, PATs, etc.), and offers more interactive debugging compared to Notebooks.
# - <b>Databricks Connect V2</b> runs Apache Spark code remotely on a Databricks cluster from a local environment. It is ideal for interactive debugging and remote Spark job execution, with an easy setup: `pip install databricks-connect>=<your version>`.
# - The <b>Databricks VS Code Extension</b> integrates Databricks into VS Code for batch and interactive development, simplifies setup with resource explorers and the Databricks CLI, supports running and debugging Python files on clusters, and keeps developers within VS Code while providing DAB features.
#
# </details>

# %% [markdown]
# ### A2. The Databricks Extension for VS Code
#
# <div style="display:grid;grid-template-columns:minmax(0,0.85fr) minmax(0,1.15fr);gap:30px;max-width:1150px;margin:0 auto;font-family:sans-serif;align-items:center;">
#   <div>
#     <div style="margin-bottom:22px;">
#   <div style="font-size:15pt;font-weight:700;color:#0b2026;margin-bottom:4px;">Simple Setup</div>
#   <div style="font-size:13pt;color:#0b2026;line-height:1.45;">Find us on the VS Code Marketplace and get connected to compute in minutes.</div>
# </div>
#     <div style="margin-bottom:22px;">
#   <div style="font-size:15pt;font-weight:700;color:#0b2026;margin-bottom:4px;">Native Experience</div>
#   <div style="font-size:13pt;color:#0b2026;line-height:1.45;">Write code using the productivity features you love from VS Code.</div>
# </div>
#     <div style="margin-bottom:22px;">
#   <div style="font-size:15pt;font-weight:700;color:#0b2026;margin-bottom:4px;">Run on Databricks</div>
#   <div style="font-size:13pt;color:#0b2026;line-height:1.45;">Execute batch workloads or start interactively debugging directly from your IDE.</div>
# </div>
#   </div>
#   <div style="text-align:center;">
#     <img src="https://files.training.databricks.com/binder/prod_main/automated-deployment-with-declarative-automation-bundles-en_us-2.4.0/images/20260828T161450Z/Automated Deployment with Declarative Automation Bundles/Includes/images/lecture_vscode/vscode-extension-demo.gif" alt="Databricks extension for VS Code" style="width:100%;max-width:640px;border:1px solid #d0d7dd;border-radius:8px;">
#   </div>
# </div>
#
# ##### Additional notes
#
# <details>
#
# - The VS Code extension has a simple setup from the VS Code Marketplace, getting you connected to compute in minutes.
# - It provides a native experience for developers who prefer VS Code, letting you write code with the productivity features you already use.
# - You can run code on Databricks directly from your IDE &mdash; executing batch workloads or starting interactive debugging.
#
# </details>

# %% [markdown]
# ## B. Conclusion
#
# - Three tools bring Databricks into local development: the **CLI** (scripting, CI/CD), **Databricks Connect V2** (remote Spark, debugging), and the **VS Code Extension** (full IDE integration with DAB features).
# - Together they let you build, debug, and deploy bundles from your own machine.
#
# ### Next Steps
#
# In the next demo, you will use VS Code with Databricks.

# %% [markdown]
# &copy; 2026 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
