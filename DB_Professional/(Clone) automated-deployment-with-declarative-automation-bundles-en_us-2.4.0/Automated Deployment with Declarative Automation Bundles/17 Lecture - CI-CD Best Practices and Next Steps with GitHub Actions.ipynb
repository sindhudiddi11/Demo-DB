# %% [markdown]
# ![Databricks Academy](https://files.training.databricks.com/binder/prod_main/automated-deployment-with-declarative-automation-bundles-en_us-2.4.0/images/20260828T161450Z/Automated Deployment with Declarative Automation Bundles/Includes/images/common/db-academy.png)

# %% [markdown]
# # Lecture - CI/CD Best Practices & Next Steps with GitHub Actions
#
# ## Overview
#
# This lecture brings together two closing topics. First, a set of general **best practices** to keep in mind when implementing CI/CD for data engineering. Then a look at **next steps**: how DABs combine with **GitHub Actions** to automate deployment across environments using a GitFlow-style branching pattern, closing with a note on Git tools you can integrate with Databricks.
#
# ## Learning Objectives
#
# By the end of this lecture, you will be able to:
# 1. **Summarize** the key best practices for implementing CI/CD in data engineering.
# 2. **Describe** a deployment pattern that combines DABs with GitHub Actions and a GitFlow branching strategy.
# 3. **Identify** common Git tools and services that integrate with Databricks.

# %% [markdown]
# ## A. CI/CD Best Practices for Data Engineering

# %% [markdown]
# ### A1. Five Practices to Remember
#
# Effective CI/CD for data engineering rests on five practices.
# <div style="display:grid;grid-template-columns:1fr 1fr;gap:16px;max-width:1150px;margin:0 auto;font-family:sans-serif;">
#   <div style="display:flex;gap:14px;align-items:flex-start;background:#F9F7F4;border-radius:8px;padding:14px 16px;border-left:5px solid #00A972;box-shadow:0 2px 8px rgba(27,49,57,0.06);">
#   <div style="flex:0 0 auto;"><img src="data:image/png;base64,..." alt="Define a Clear Testing Strategy" style="height:40px;vertical-align:middle;"/></div>
#   <div><div style="font-size:14.5pt;font-weight:700;color:#0b2026;margin-bottom:3px;">Define a Clear Testing Strategy</div><div style="font-size:12.5pt;color:#0b2026;line-height:1.4;">Establish and automate unit, integration, and end-to-end tests.</div></div>
# </div>
#   <div style="display:flex;gap:14px;align-items:flex-start;background:#F9F7F4;border-radius:8px;padding:14px 16px;border-left:5px solid #98102A;box-shadow:0 2px 8px rgba(27,49,57,0.06);">
#   <div style="flex:0 0 auto;"><img src="data:image/png;base64,..." alt="Automate Deployment with DABs" style="height:40px;vertical-align:middle;"/></div>
#   <div><div style="font-size:14.5pt;font-weight:700;color:#0b2026;margin-bottom:3px;">Automate Deployment with DABs</div><div style="font-size:12.5pt;color:#0b2026;line-height:1.4;">Use DABs for consistent, repeatable, and automated deployments in Databricks.</div></div>
# </div>
#   <div style="display:flex;gap:14px;align-items:flex-start;background:#F9F7F4;border-radius:8px;padding:14px 16px;border-left:5px solid #4299E0;box-shadow:0 2px 8px rgba(27,49,57,0.06);">
#   <div style="flex:0 0 auto;"><img src="data:image/png;base64,..." alt="Implement a Version Control Strategy" style="height:40px;vertical-align:middle;"/></div>
#   <div><div style="font-size:14.5pt;font-weight:700;color:#0b2026;margin-bottom:3px;">Implement a Version Control Strategy</div><div style="font-size:12.5pt;color:#0b2026;line-height:1.4;">Use a version control system like git to manage code and define branching strategies.</div></div>
# </div>
#   <div style="display:flex;gap:14px;align-items:flex-start;background:#F9F7F4;border-radius:8px;padding:14px 16px;border-left:5px solid #618794;box-shadow:0 2px 8px rgba(27,49,57,0.06);">
#   <div style="flex:0 0 auto;"><img src="data:image/png;base64,..." alt="Monitor and Optimize CI/CD Pipelines" style="height:40px;vertical-align:middle;"/></div>
#   <div><div style="font-size:14.5pt;font-weight:700;color:#0b2026;margin-bottom:3px;">Monitor and Optimize CI/CD Pipelines</div><div style="font-size:12.5pt;color:#0b2026;line-height:1.4;">Continuously monitor the performance of your CI/CD pipelines.</div></div>
# </div>
#   <div style="display:flex;gap:14px;align-items:flex-start;background:#F9F7F4;border-radius:8px;padding:14px 16px;border-left:5px solid #FFAB00;box-shadow:0 2px 8px rgba(27,49,57,0.06);">
#   <div style="flex:0 0 auto;"><img src="data:image/png;base64,..." alt="Establish a Code Review Process" style="height:40px;vertical-align:middle;"/></div>
#   <div><div style="font-size:14.5pt;font-weight:700;color:#0b2026;margin-bottom:3px;">Establish a Code Review Process</div><div style="font-size:12.5pt;color:#0b2026;line-height:1.4;">Set up mandatory code reviews to ensure the quality of changes before they are merged.</div></div>
# </div>
# </div>
#
# ##### Additional notes
#
# <details>
#
# - Define a clear testing strategy that includes unit, integration, and end-to-end tests. Automating these ensures code functions correctly and data integrity is maintained before deployment.
# - Implement a version control strategy using a system like git to manage code, notebooks, and configuration files, and define a branching strategy to manage development stages.
# - Establish a robust code review process &mdash; peer reviews ensure changes are vetted before merge, and CI tools can trigger builds on pull requests to catch issues early.
# - Automate deployment with Declarative Automation Bundles (DABs) for consistent, repeatable deployments, minimizing human error and ensuring the right code reaches the right environment.
# - Continuously monitor and optimize the performance of your CI/CD pipelines &mdash; gather feedback, identify bottlenecks, and improve automation efficiency.
#
# </details>

# %% [markdown]
# ### A2. Implementing CI/CD
#
# <div style="font-family:sans-serif;max-width:1100px;margin:0 auto;">
# <div style="display:flex;align-items:center;gap:20px;width:100%;border-radius:10px;padding:22px 26px;background:rgba(240,165,0,0.18);border-left:8px solid #F0A500;box-shadow:0 2px 10px rgba(27,49,57,0.08);">
#   <div style="width:56px;height:56px;border-radius:50%;flex-shrink:0;background:#F0A500;color:#0b2026;font-size:22pt;font-weight:700;display:flex;align-items:center;justify-content:center;">!</div>
#   <div><div style="font-size:20pt;font-weight:700;color:#0b2026;line-height:1.2;margin-bottom:4px;">Implementing CI/CD</div><div style="font-size:14.5pt;color:#0b2026;line-height:1.45;">Requires alignment across teams and establishment of robust processes that ensure continuous improvement and quality</b>.</div></div>
# </div></div>
#
# ##### Additional notes
#
# <details>
#
# - Implementing CI/CD requires alignment across teams and the establishment of robust processes that ensure continuous improvement and quality.
# - For more detailed guidance, see the Databricks documentation on best practices for operational excellence.
#
# </details>

# %% [markdown]
# ## B. Next Steps: Automated Deployment with GitHub Actions

# %% [markdown]
# ### B1. Deployment Patterns with DABs and GitHub Actions
#
# Branches (feature, dev, release, main, hotfix) trigger GitHub Actions workflows that deploy DABs to the matching Databricks workspace (development, QA, production).
#
# <div style="text-align:center;"><svg viewBox="0 0 1160 560" xmlns="http://www.w3.org/2000/svg" style="width:100%;height:auto;max-width:1160px;font-family:Helvetica,Arial,sans-serif;">
#   <defs><marker id="ga" markerWidth="8" markerHeight="8" refX="6" refY="3" orient="auto"><path d="M0,0 L6,3 L0,6 Z" fill="#FF5F46"/></marker></defs>
#   <!-- branch row -->
#   <rect x="60" y="20" width="90" height="70" rx="6" fill="#F0A500"/><image href="data:image/png;base64,..." x="90" y="26" width="30" height="30"/><rect x="70" y="62" width="70" height="22" rx="3" fill="#0b2026"/><text x="105" y="77" font-family="Helvetica,Arial,sans-serif" font-size="12" font-weight="700" fill="#fff" text-anchor="middle">feature</text>
#   <rect x="300" y="20" width="90" height="70" rx="6" fill="#F0A500"/><image href="data:image/png;base64,..." x="330" y="26" width="30" height="30"/><rect x="310" y="62" width="70" height="22" rx="3" fill="#0b2026"/><text x="345" y="77" font-family="Helvetica,Arial,sans-serif" font-size="12" font-weight="700" fill="#fff" text-anchor="middle">dev</text>
#   <rect x="560" y="20" width="90" height="70" rx="6" fill="#F0A500"/><image href="data:image/png;base64,..." x="590" y="26" width="30" height="30"/><rect x="570" y="62" width="70" height="22" rx="3" fill="#0b2026"/><text x="605" y="77" font-family="Helvetica,Arial,sans-serif" font-size="12" font-weight="700" fill="#fff" text-anchor="middle">release</text>
#   <rect x="800" y="20" width="90" height="70" rx="6" fill="#F0A500"/><image href="data:image/png;base64,..." x="830" y="26" width="30" height="30"/><rect x="810" y="62" width="70" height="22" rx="3" fill="#0b2026"/><text x="845" y="77" font-family="Helvetica,Arial,sans-serif" font-size="12" font-weight="700" fill="#fff" text-anchor="middle">main</text>
#   <rect x="1040" y="20" width="90" height="70" rx="6" fill="#F0A500"/><image href="data:image/png;base64,..." x="1070" y="26" width="30" height="30"/><rect x="1050" y="62" width="70" height="22" rx="3" fill="#0b2026"/><text x="1085" y="77" font-family="Helvetica,Arial,sans-serif" font-size="12" font-weight="700" fill="#fff" text-anchor="middle">hotfix</text>
#   <!-- branch arrows -->
#   <text x="230" y="48" font-family="Helvetica,Arial,sans-serif" font-size="11" fill="#0b2026" text-anchor="middle">PR</text>
#   <path d="M150,55 L296,55" stroke="#FF5F46" stroke-width="2" fill="none" marker-end="url(#ga)"/>
#   <path d="M390,55 L556,55" stroke="#FF5F46" stroke-width="2" fill="none" marker-end="url(#ga)"/>
#   <text x="490" y="42" font-family="Helvetica,Arial,sans-serif" font-size="10" fill="#0b2026" text-anchor="middle">Approve PR</text><text x="490" y="54" font-family="Helvetica,Arial,sans-serif" font-size="10" fill="#0b2026" text-anchor="middle">and merge</text>
#   <path d="M650,55 L796,55" stroke="#FF5F46" stroke-width="2" fill="none" marker-end="url(#ga)"/>
#   <text x="725" y="42" font-family="Helvetica,Arial,sans-serif" font-size="10" fill="#0b2026" text-anchor="middle">Approve</text><text x="725" y="54" font-family="Helvetica,Arial,sans-serif" font-size="10" fill="#0b2026" text-anchor="middle">PR and merge</text>
#   <path d="M1040,55 L894,55" stroke="#FF5F46" stroke-width="2" fill="none" marker-end="url(#ga)"/>
#   <text x="965" y="42" font-family="Helvetica,Arial,sans-serif" font-size="10" fill="#0b2026" text-anchor="middle">Approve</text><text x="965" y="54" font-family="Helvetica,Arial,sans-serif" font-size="10" fill="#0b2026" text-anchor="middle">PR and merge</text>
#   <!-- feature down annotations -->
#   <text x="30" y="150" font-family="Helvetica,Arial,sans-serif" font-size="10.5" fill="#0b2026" text-anchor="start">Create</text><text x="30" y="163" font-family="Helvetica,Arial,sans-serif" font-size="10.5" fill="#0b2026" text-anchor="start">feature</text><text x="30" y="176" font-family="Helvetica,Arial,sans-serif" font-size="10.5" fill="#0b2026" text-anchor="start">branch</text>
#   <text x="150" y="175" font-family="Helvetica,Arial,sans-serif" font-size="10.5" fill="#0b2026" text-anchor="start">commit</text>
#   <text x="210" y="205" font-family="Helvetica,Arial,sans-serif" font-size="10.5" fill="#0b2026" text-anchor="start">Manually</text><text x="210" y="218" font-family="Helvetica,Arial,sans-serif" font-size="10.5" fill="#0b2026" text-anchor="start">Deploy</text>
#   <path d="M95,90 L95,400" stroke="#FF5F46" stroke-width="1.5" fill="none" marker-end="url(#ga)"/>
#   <path d="M130,90 L130,400" stroke="#FF5F46" stroke-width="1.5" fill="none" marker-end="url(#ga)"/>
#   <path d="M170,90 L170,400" stroke="#FF5F46" stroke-width="1.5" fill="none" marker-end="url(#ga)"/>
#   <!-- GH Actions workflow boxes -->
#   <rect x="430" y="150" width="200" height="164" rx="8" fill="#4A6670"/><text x="530" y="172" font-family="Helvetica,Arial,sans-serif" font-size="12.5" fill="#fff" text-anchor="middle">GitHub Actions</text><text x="530" y="188" font-family="Helvetica,Arial,sans-serif" font-size="12.5" fill="#fff" text-anchor="middle">Workflow</text><rect x="442" y="190" width="176" height="32" rx="4" fill="#F1EEE9"/><text x="530" y="204" font-family="Helvetica,Arial,sans-serif" font-size="11" fill="#0b2026" text-anchor="middle">Deploy to stage</text><rect x="442" y="230" width="176" height="32" rx="4" fill="#F1EEE9"/><text x="530" y="242" font-family="Helvetica,Arial,sans-serif" font-size="11" fill="#0b2026" text-anchor="middle">Run Tests</text><text x="530" y="256" font-family="Helvetica,Arial,sans-serif" font-size="11" fill="#0b2026" text-anchor="middle">Code Coverage</text><text x="530" y="270" font-family="Helvetica,Arial,sans-serif" font-size="11" fill="#0b2026" text-anchor="middle">Security Scans</text><rect x="442" y="270" width="176" height="32" rx="4" fill="#F1EEE9"/><text x="530" y="282" font-family="Helvetica,Arial,sans-serif" font-size="11" fill="#0b2026" text-anchor="middle">Create PR from dev</text><text x="530" y="296" font-family="Helvetica,Arial,sans-serif" font-size="11" fill="#0b2026" text-anchor="middle">to stage</text>
#   <rect x="720" y="150" width="200" height="164" rx="8" fill="#4A6670"/><text x="820" y="172" font-family="Helvetica,Arial,sans-serif" font-size="12.5" fill="#fff" text-anchor="middle">GitHub Actions</text><text x="820" y="188" font-family="Helvetica,Arial,sans-serif" font-size="12.5" fill="#fff" text-anchor="middle">Workflow</text><rect x="732" y="190" width="176" height="32" rx="4" fill="#F1EEE9"/><text x="820" y="204" font-family="Helvetica,Arial,sans-serif" font-size="11" fill="#0b2026" text-anchor="middle">Deploy to prod</text><rect x="732" y="230" width="176" height="32" rx="4" fill="#F1EEE9"/><text x="820" y="244" font-family="Helvetica,Arial,sans-serif" font-size="11" fill="#0b2026" text-anchor="middle">Create release tag</text><rect x="732" y="270" width="176" height="32" rx="4" fill="#F1EEE9"/><text x="820" y="282" font-family="Helvetica,Arial,sans-serif" font-size="11" fill="#0b2026" text-anchor="middle">Create PR from dev</text><text x="820" y="296" font-family="Helvetica,Arial,sans-serif" font-size="11" fill="#0b2026" text-anchor="middle">to main</text>
#   <rect x="1000" y="150" width="200" height="124" rx="8" fill="#4A6670"/><text x="1100" y="172" font-family="Helvetica,Arial,sans-serif" font-size="12.5" fill="#fff" text-anchor="middle">GitHub Actions</text><text x="1100" y="188" font-family="Helvetica,Arial,sans-serif" font-size="12.5" fill="#fff" text-anchor="middle">Workflow</text><rect x="1012" y="190" width="176" height="32" rx="4" fill="#F1EEE9"/><text x="1100" y="202" font-family="Helvetica,Arial,sans-serif" font-size="11" fill="#0b2026" text-anchor="middle">Create hotfix</text><text x="1100" y="216" font-family="Helvetica,Arial,sans-serif" font-size="11" fill="#0b2026" text-anchor="middle">branch</text><rect x="1012" y="230" width="176" height="32" rx="4" fill="#F1EEE9"/><text x="1100" y="242" font-family="Helvetica,Arial,sans-serif" font-size="11" fill="#0b2026" text-anchor="middle">Create PR hotfix</text><text x="1100" y="256" font-family="Helvetica,Arial,sans-serif" font-size="11" fill="#0b2026" text-anchor="middle">to main</text>
#   <!-- dev -> stage workflow -->
#   <path d="M345,90 L345,196 L426,196" stroke="#FF5F46" stroke-width="1.5" fill="none" marker-end="url(#ga)"/>
#   <path d="M630,196 L605,196 L605,90" stroke="#FF5F46" stroke-width="1.5" fill="none" marker-end="url(#ga)"/>
#   <path d="M845,90 L845,146" stroke="#FF5F46" stroke-width="1.5" fill="none" marker-end="url(#ga)"/>
#   <path d="M1085,90 L1085,146" stroke="#FF5F46" stroke-width="1.5" fill="none" marker-end="url(#ga)"/>
#   <!-- Databricks workspaces zone -->
#   <rect x="40" y="420" width="1080" height="130" rx="10" fill="#1B5162"/>
#   <text x="560" y="448" font-family="Helvetica,Arial,sans-serif" font-size="15" font-weight="700" fill="#fff" text-anchor="middle">Databricks Workspaces</text>
#   <rect x="70" y="460" width="300" height="78" rx="8" fill="#FF5F46"/><text x="220" y="486" font-family="Helvetica,Arial,sans-serif" font-size="12.5" font-weight="700" fill="#fff" text-anchor="middle">Development workspace</text><rect x="90" y="496" width="260" height="30" rx="5" fill="none" stroke="#fff" stroke-width="1.2"/><text x="220" y="516" font-family="Helvetica,Arial,sans-serif" font-size="11.5" fill="#fff" text-anchor="middle">Development deployment</text>
#   <rect x="430" y="460" width="300" height="78" rx="8" fill="#FF5F46"/><text x="580" y="486" font-family="Helvetica,Arial,sans-serif" font-size="12.5" font-weight="700" fill="#fff" text-anchor="middle">QA workspace</text><rect x="450" y="496" width="260" height="30" rx="5" fill="none" stroke="#fff" stroke-width="1.2"/><text x="580" y="516" font-family="Helvetica,Arial,sans-serif" font-size="11.5" fill="#fff" text-anchor="middle">QA deployment</text>
#   <rect x="790" y="460" width="300" height="78" rx="8" fill="#FF5F46"/><text x="940" y="486" font-family="Helvetica,Arial,sans-serif" font-size="12.5" font-weight="700" fill="#fff" text-anchor="middle">Production workspace</text><rect x="810" y="496" width="260" height="30" rx="5" fill="none" stroke="#fff" stroke-width="1.2"/><text x="940" y="516" font-family="Helvetica,Arial,sans-serif" font-size="11.5" fill="#fff" text-anchor="middle">Production deployment</text>
#   <!-- workflow -> workspace deploy arrows -->
#   <path d="M530,330 L530,455" stroke="#FF5F46" stroke-width="1.5" fill="none" marker-end="url(#ga)"/>
#   <path d="M820,330 L900,455" stroke="#FF5F46" stroke-width="1.5" fill="none" marker-end="url(#ga)"/>
# </svg></div>
#
# <div style="max-width:1150px;margin:16px auto 0 auto;font-family:sans-serif;display:grid;grid-template-columns:1fr 1fr;gap:12px;">
#   <div style="display:flex;gap:10px;"><span style="flex:0 0 24px;width:24px;height:24px;border-radius:50%;background:#FF5F46;color:#fff;font-weight:700;font-size:12pt;display:flex;align-items:center;justify-content:center;">1</span><span style="font-size:12.5pt;color:#0b2026;">Easily integrate structured branching patterns like <b>GitFlow</b> with DABs.</span></div>
#   <div style="display:flex;gap:10px;"><span style="flex:0 0 24px;width:24px;height:24px;border-radius:50%;background:#FF5F46;color:#fff;font-weight:700;font-size:12pt;display:flex;align-items:center;justify-content:center;">2</span><span style="font-size:12.5pt;color:#0b2026;">Developers create isolated <b>feature</b> branches and open a PR once development is complete and assets are ready for QA.</span></div>
#   <div style="display:flex;gap:10px;"><span style="flex:0 0 24px;width:24px;height:24px;border-radius:50%;background:#FF5F46;color:#fff;font-weight:700;font-size:12pt;display:flex;align-items:center;justify-content:center;">3</span><span style="font-size:12.5pt;color:#0b2026;">After code review, merge branches into <b>dev</b>, triggering GitHub Actions workflows.</span></div>
#   <div style="display:flex;gap:10px;"><span style="flex:0 0 24px;width:24px;height:24px;border-radius:50%;background:#FF5F46;color:#fff;font-weight:700;font-size:12pt;display:flex;align-items:center;justify-content:center;">4</span><span style="font-size:12.5pt;color:#0b2026;">Critical production issues are handled through <b>hotfix</b> branches from main, merged back into both main and dev.</span></div>
# </div>
#
# ##### Additional notes
#
# <details>
#
# - This is a high-level overview of integrating GitFlow (a branching model using feature branches and multiple primary branches) with DABs, using GitHub Actions for automation.
# - A developer creates a feature branch from dev, where features or bug fixes are developed in isolation, and can deploy directly to the DEV workspace using the Databricks CLI.
# - Once a feature is complete, a pull request is opened; after peer review, it is merged into dev.
# - Merging into dev triggers a GitHub Actions workflow that deploys to the QA environment using DABs, runs tests, code coverage, and security scans, creates a release branch, and opens a PR to main.
# - After the release PR is closed, another workflow deploys the bundle to prod, creates a release tag, and opens a PR from main back to dev.
# - Critical production issues are handled with a hotfix branch from main, merged back into both main and dev after the fix &mdash; keeping production stable while development continues.
#
# </details>

# %% [markdown]
# ## C. Git with Databricks

# %% [markdown]
# ### C1. Overview of Git with Databricks
#
# Git is a free, open-source framework for tracking source-code changes during software development. You can integrate third-party Git tools and services that fit your organization's needs.
# <div style="display:flex;flex-wrap:wrap;gap:8px;max-width:1000px;margin:0 auto;font-family:sans-serif;"><span style="background:rgba(255,95,70,0.08);border:1px solid #4299E0;border-radius:16px;padding:6px 16px;font-size:14pt;color:#0b2026;">GitHub</span><span style="background:rgba(255,95,70,0.08);border:1px solid #4299E0;border-radius:16px;padding:6px 16px;font-size:14pt;color:#0b2026;">GitHub Actions</span><span style="background:rgba(255,95,70,0.08);border:1px solid #4299E0;border-radius:16px;padding:6px 16px;font-size:14pt;color:#0b2026;">GitLab</span><span style="background:rgba(255,95,70,0.08);border:1px solid #4299E0;border-radius:16px;padding:6px 16px;font-size:14pt;color:#0b2026;">Azure DevOps</span><span style="background:rgba(255,95,70,0.08);border:1px solid #4299E0;border-radius:16px;padding:6px 16px;font-size:14pt;color:#0b2026;">Bitbucket</span></div>
#
# ##### Additional notes
#
# <details>
#
# - Git is a free and open-source software framework designed to track changes in source code during software development.
# - Version control enables tracking code changes for rollback and collaboration; branching and merging let multiple developers work in parallel; and a distributed workflow gives each developer a full local repository.
# - You can integrate third-party Git tools and services &mdash; such as GitHub, GitHub Actions, GitLab, Azure DevOps, and Bitbucket &mdash; that make sense for your organizational needs.
# - Databricks provides a user-friendly interface for common Git operations, lets you use remote Git repos while developing in notebooks, and offers a Repos REST API to automate Git workflows in CI/CD pipelines.
#
# </details>

# %% [markdown]
# ## D. Conclusion
#
# - Effective CI/CD for data engineering rests on five practices: a clear **testing** strategy, a **version control** strategy, a **code review** process, **automated deployment with DABs**, and ongoing **monitoring and optimization**.
# - **DABs + GitHub Actions** automate deployment: branches map to environments, and Actions workflows deploy bundles while running tests, coverage, and security scans.
# - A **GitFlow-style** pattern (feature, dev, release, main, hotfix) fits naturally with DABs.
# - Databricks integrates with common **Git tools and services** &mdash; choose what fits your organization.
#
# ### Next Steps
#
# This concludes the course content. Review the summary and next-steps material, and revisit any demos or labs as needed.

# %% [markdown]
# &copy; 2026 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
