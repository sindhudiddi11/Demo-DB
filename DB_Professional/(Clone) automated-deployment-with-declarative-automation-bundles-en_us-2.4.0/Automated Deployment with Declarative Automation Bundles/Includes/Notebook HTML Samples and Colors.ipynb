# %% [markdown]
# <div style="
#   border-left: 4px solid #1976d2;
#   background: #e3f2fd;
#   padding: 14px 18px;
#   border-radius: 4px;
#   margin: 16px 0;
# ">
#   <strong style="display:block; color:#0d47a1; margin-bottom:6px; font-size: 1.1em;">
#     Information
#   </strong>
#   <div style="color:#333;">
# In this training, we use <strong>Lakebase Provisioned</strong>.
# For future use, we recommend <strong>Lakebase Autoscaling</strong>, which supports additional features beyond the core concepts covered here.
#   </div>
# </div>

# %% [markdown]
# <div style="
#   border-left: 4px solid #ff9800;
#   background: #fff3e0;
#   padding: 14px 18px;
#   border-radius: 4px;
#   margin: 16px 0;
# ">
#   <strong style="display:block; color:#e65100; margin-bottom:6px; font-size: 1.1em;">
#     Warning
#   </strong>
#   <div style="color:#333;">
# PostgreSQL does not support cross-database queries, so you can only query the database selected as your default.
#   </div>
# </div>

# %% [markdown]
# <div style="
#   border-left: 4px solid #f44336;
#   background: #ffebee;
#   padding: 14px 18px;
#   border-radius: 4px;
#   margin: 16px 0;
# ">
#   <strong style="display:block; color:#c62828; margin-bottom:6px; font-size: 1.1em;">Error</strong>
#   <div style="color:#333;">
#     This is an error message. Use this style to highlight critical issues, errors, or anti-patterns that should be avoided.
#   </div>
# </div>

# %% [markdown]
# <div style="
#   border-left: 4px solid #4caf50;
#   background: #e8f5e9;
#   padding: 14px 18px;
#   border-radius: 4px;
#   margin: 16px 0;
# ">
#   <strong style="display:block; color:#2e7d32; margin-bottom:6px; font-size: 1.1em;">Success</strong>
#   <div style="color:#333;">
#     This is an error message. Use this style to highlight critical issues, errors, or anti-patterns that should be avoided.
#   </div>
# </div>

# %% [markdown]
# <div style="
#   border-left: 4px solid #7b1fa2;
#   background: #f3e5f5;
#   padding: 14px 18px;
#   border-radius: 4px;
#   margin: 16px 0;
# ">
#   <strong style="display:block; color:#4a148c; margin-bottom:6px; font-size: 1.1em;">Notes</strong>
#   <div style="color:#333;">
#     This is a note. Use this style to highlight important remarks or observations that the reader should keep in mind.
#   </div>
# </div>

# %% [markdown]
# ## Theme Light
#
# | Color | Hex |
# |------|------|
# | <span style="display:inline-block;width:18px;height:18px;background:#0b2026;border:1px solid #ccc;"></span> | #0b2026 |
# | <span style="display:inline-block;width:18px;height:18px;background:#F9F7F4;border:1px solid #ccc;"></span> | #F9F7F4 |
# | <span style="display:inline-block;width:18px;height:18px;background:#FF5F46;border:1px solid #ccc;"></span> | #FF5F46 |
# | <span style="display:inline-block;width:18px;height:18px;background:#EEEDE9;border:1px solid #ccc;"></span> | #EEEDE9 |
# | <span style="display:inline-block;width:18px;height:18px;background:#1B5162;border:1px solid #ccc;"></span> | #1B5162 |
# | <span style="display:inline-block;width:18px;height:18px;background:#00A972;border:1px solid #ccc;"></span> | #00A972 |
# | <span style="display:inline-block;width:18px;height:18px;background:#98102A;border:1px solid #ccc;"></span> | #98102A |
# | <span style="display:inline-block;width:18px;height:18px;background:#FFAB00;border:1px solid #ccc;"></span> | #FFAB00 |
# | <span style="display:inline-block;width:18px;height:18px;background:#618794;border:1px solid #ccc;"></span> | #618794 |
# | <span style="display:inline-block;width:18px;height:18px;background:#4299E0;border:1px solid #ccc;"></span> | #4299E0 |
#
# ---
#
# ## Custom
#
# | Color | Hex |
# |------|------|
# | <span style="display:inline-block;width:18px;height:18px;background:#C2C2C2;border:1px solid #ccc;"></span> | #C2C2C2 |
# | <span style="display:inline-block;width:18px;height:18px;background:#801C17;border:1px solid #ccc;"></span> | #801C17 |
# | <span style="display:inline-block;width:18px;height:18px;background:#FABFBA;border:1px solid #ccc;"></span> | #FABFBA |
# | <span style="display:inline-block;width:18px;height:18px;background:#FF9E94;border:1px solid #ccc;"></span> | #FF9E94 |
# | <span style="display:inline-block;width:18px;height:18px;background:#FF3621;border:1px solid #ccc;"></span> | #FF3621 |
# | <span style="display:inline-block;width:18px;height:18px;background:#FF6952;border:1px solid #ccc;"></span> | #FF6952 |
# | <span style="display:inline-block;width:18px;height:18px;background:#FF5F46;border:1px solid #ccc;"></span> | #FF5F46 |
# | <span style="display:inline-block;width:18px;height:18px;background:#FF8774;border:1px solid #ccc;"></span> | #FF8774 |
# | <span style="display:inline-block;width:18px;height:18px;background:#CD7F32;border:1px solid #ccc;"></span> | #CD7F32 |
# | <span style="display:inline-block;width:18px;height:18px;background:#F9F7F4;border:1px solid #ccc;"></span> | #F9F7F4 |
# | <span style="display:inline-block;width:18px;height:18px;background:#FFCC66;border:1px solid #ccc;"></span> | #FFCC66 |
# | <span style="display:inline-block;width:18px;height:18px;background:#FFAB00;border:1px solid #ccc;"></span> | #FFAB00 |
# | <span style="display:inline-block;width:18px;height:18px;background:#EEEDE9;border:1px solid #ccc;"></span> | #EEEDE9 |
# | <span style="display:inline-block;width:18px;height:18px;background:#00A972;border:1px solid #ccc;"></span> | #00A972 |
# | <span style="display:inline-block;width:18px;height:18px;background:#0B2026;border:1px solid #ccc;"></span> | #0B2026 |
# | <span style="display:inline-block;width:18px;height:18px;background:#618794;border:1px solid #ccc;"></span> | #618794 |
# | <span style="display:inline-block;width:18px;height:18px;background:#1B3139;border:1px solid #ccc;"></span> | #1B3139 |
# | <span style="display:inline-block;width:18px;height:18px;background:#5A6F77;border:1px solid #ccc;"></span> | #5A6F77 |
# | <span style="display:inline-block;width:18px;height:18px;background:#DCE0E2;border:1px solid #ccc;"></span> | #DCE0E2 |
# | <span style="display:inline-block;width:18px;height:18px;background:#303F47;border:1px solid #ccc;"></span> | #303F47 |
# | <span style="display:inline-block;width:18px;height:18px;background:#90A5B1;border:1px solid #ccc;"></span> | #90A5B1 |
# | <span style="display:inline-block;width:18px;height:18px;background:#2272B4;border:1px solid #ccc;"></span> | #2272B4 |
# | <span style="display:inline-block;width:18px;height:18px;background:#C4CCD6;border:1px solid #ccc;"></span> | #C4CCD6 |
# | <span style="display:inline-block;width:18px;height:18px;background:#98102A;border:1px solid #ccc;"></span> | #98102A |
