# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img
#     src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png"
#     alt="Databricks Learning"
#   >
# </div>

# %% [markdown]
# # Summary and Next Steps

# %% [markdown]
# <div style="max-width: 1200px; margin: 0 auto; font-family: sans-serif; color: #0b2026;">
#
# <!-- Title -->
# <div style="text-align: center; margin-bottom: 28px;">
#   <div style="font-size: 15pt; color: #618794; margin-top: 6px;">The performance optimization toolkit</div>
# </div>
#
# <!-- ===== ROW 1: Data Layout → Query Execution → Diagnose ===== -->
# <div style="display: flex; justify-content: center; align-items: stretch; gap: 0;">
#
#   <!-- 1. Data Layout -->
#   <div style="flex: 1; max-width: 280px; background: #F9F7F4; border-radius: 10px; padding: 18px 16px; box-shadow: 0 2px 8px rgba(27,49,57,0.06); text-align: center; border-top: 6px solid #4299E0;">
#     <div style="font-size: 15pt; font-weight: 700; color: #0b2026; margin-bottom: 10px;">Data Layout</div>
#     <div style="font-size: 14pt; color: #618794; line-height: 1.6; text-align: left;">
#       <div style="margin-bottom: 4px;">Partitioning strategy</div>
#       <div style="margin-bottom: 4px;">File sizing</div>
#       <div style="margin-bottom: 4px;">ZORDER</div>
#       <div>Liquid Clustering</div>
#     </div>
#   </div>
#
#   <!-- Arrow -->
#   <div style="display: flex; align-items: center; padding: 0 10px; font-size: 26pt; color: #618794;">&#10132;</div>
#
#   <!-- 2. Query Execution -->
#   <div style="flex: 1.1; max-width: 300px; background: #1B5162; border-radius: 10px; padding: 18px 16px; box-shadow: 0 2px 8px rgba(27,49,57,0.06); text-align: center; border-top: 6px solid #FF5F46;">
#     <div style="font-size: 15pt; font-weight: 700; color: white; margin-bottom: 10px;">Query Execution</div>
#     <div style="display: flex; flex-direction: column; gap: 5px;">
#       <div style="background: rgba(255,255,255,0.15); border-radius: 5px; padding: 6px 10px; font-size: 14pt; color: white;">Shuffle &amp; Broadcast Joins</div>
#       <div style="background: rgba(255,255,255,0.15); border-radius: 5px; padding: 6px 10px; font-size: 14pt; color: white;">Join Ordering &amp; Spill</div>
#       <div style="background: rgba(255,255,255,0.15); border-radius: 5px; padding: 6px 10px; font-size: 14pt; color: white;">ANALYZE TABLE &amp; CBO</div>
#       <div style="background: rgba(255,255,255,0.15); border-radius: 5px; padding: 6px 10px; font-size: 14pt; color: white;">UDF Optimization</div>
#     </div>
#   </div>
#
#   <!-- Arrow -->
#   <div style="display: flex; align-items: center; padding: 0 10px; font-size: 26pt; color: #618794;">&#10132;</div>
#
#   <!-- 3. Diagnose & Optimize -->
#   <div style="flex: 1; max-width: 280px; background: #F9F7F4; border-radius: 10px; padding: 18px 16px; box-shadow: 0 2px 8px rgba(27,49,57,0.06); text-align: center; border-top: 6px solid #00A972;">
#     <div style="font-size: 15pt; font-weight: 700; color: #0b2026; margin-bottom: 10px;">Diagnose &amp; Optimize</div>
#     <div style="font-size: 14pt; color: #618794; line-height: 1.6;">
#       Use the Spark UI to identify bottlenecks, measure improvements, and validate optimizations
#     </div>
#   </div>
#
# </div>
#
# <!-- ===== ITERATE LOOP BAR ===== -->
# <div style="margin: 16px auto 0 auto; max-width: 1050px; display: flex; align-items: center; justify-content: center; gap: 12px;">
#   <div style="flex: 1; height: 4px; background: #FF5F46; border-radius: 2px;"></div>
#   <div style="background: #FF5F46; color: white; padding: 6px 22px; border-radius: 20px; font-size: 14pt; font-weight: 700; white-space: nowrap;">
#     MEASURE &amp; IMPROVE
#   </div>
#   <div style="flex: 1; height: 4px; background: #FF5F46; border-radius: 2px;"></div>
# </div>
#
# <!-- ===== COURSE JOURNEY TABLE ===== -->
# <div style="margin-top: 20px; background: #F9F7F4; border-radius: 10px; padding: 20px 24px; box-shadow: 0 2px 8px rgba(27,49,57,0.06);">
#
# <div style="font-size: 16pt; font-weight: 700; color: #1B5162; margin-bottom: 14px;">Your Journey Through the Course</div>
#
# <style>
# .journey-table td, .journey-table th {
#   font-size: 14pt !important;
# }
# </style>
#
# <table class="journey-table" style="width: 100%; border-collapse: collapse; line-height: 1.5;">
#   <thead>
#     <tr style="background: #1B5162; color: white;">
#       <th style="padding: 10px 14px; text-align: center; border: 1px solid #EEEDE9; width: 50px;">Step</th>
#       <th style="padding: 10px 14px; text-align: left; border: 1px solid #EEEDE9;">What You Did</th>
#       <th style="padding: 10px 14px; text-align: left; border: 1px solid #EEEDE9;">Key Takeaway</th>
#       <th style="padding: 10px 14px; text-align: center; border: 1px solid #EEEDE9; width: 60px;"></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr style="background: white;">
#       <td style="padding: 8px 14px; border: 1px solid #EEEDE9; text-align: center; font-weight: 700; color: #1B5162;">1</td>
#       <td style="padding: 8px 14px; border: 1px solid #EEEDE9;">Explored over-partitioning and the small file problem</td>
#       <td style="padding: 8px 14px; border: 1px solid #EEEDE9; color: #618794;">Let Spark handle file layout; avoid unnecessary partitioning</td>
#       <td style="padding: 8px 14px; border: 1px solid #EEEDE9; text-align: center; font-size: 16pt; color: #00A972;">&#10003;</td>
#     </tr>
#     <tr style="background: #F9F7F4;">
#       <td style="padding: 8px 14px; border: 1px solid #EEEDE9; text-align: center; font-weight: 700; color: #1B5162;">2</td>
#       <td style="padding: 8px 14px; border: 1px solid #EEEDE9;">Compared ZORDER and Liquid Clustering for data skipping</td>
#       <td style="padding: 8px 14px; border: 1px solid #EEEDE9; color: #618794;">Liquid Clustering is flexible and supports multiple columns without degradation</td>
#       <td style="padding: 8px 14px; border: 1px solid #EEEDE9; text-align: center; font-size: 16pt; color: #00A972;">&#10003;</td>
#     </tr>
#     <tr style="background: white;">
#       <td style="padding: 8px 14px; border: 1px solid #EEEDE9; text-align: center; font-weight: 700; color: #1B5162;">3</td>
#       <td style="padding: 8px 14px; border: 1px solid #EEEDE9;">Identified shuffle in joins and applied broadcast joins</td>
#       <td style="padding: 8px 14px; border: 1px solid #EEEDE9; color: #618794;">Broadcast joins eliminate expensive data movement for small table joins</td>
#       <td style="padding: 8px 14px; border: 1px solid #EEEDE9; text-align: center; font-size: 16pt; color: #00A972;">&#10003;</td>
#     </tr>
#     <tr style="background: #F9F7F4;">
#       <td style="padding: 8px 14px; border: 1px solid #EEEDE9; text-align: center; font-weight: 700; color: #1B5162;">4</td>
#       <td style="padding: 8px 14px; border: 1px solid #EEEDE9;">Diagnosed exploding joins and spill, then tuned join strategies</td>
#       <td style="padding: 8px 14px; border: 1px solid #EEEDE9; color: #618794;">Join order, shuffle partitions, and ANALYZE TABLE can dramatically reduce spill and runtime</td>
#       <td style="padding: 8px 14px; border: 1px solid #EEEDE9; text-align: center; font-size: 16pt; color: #00A972;">&#10003;</td>
#     </tr>
#     <tr style="background: white;">
#       <td style="padding: 8px 14px; border: 1px solid #EEEDE9; text-align: center; font-weight: 700; color: #1B5162;">5</td>
#       <td style="padding: 8px 14px; border: 1px solid #EEEDE9;">Compared Python UDFs and SQL UDFs for performance</td>
#       <td style="padding: 8px 14px; border: 1px solid #EEEDE9; color: #618794;">Prefer native Spark/SQL functions; repartition when UDFs are necessary</td>
#       <td style="padding: 8px 14px; border: 1px solid #EEEDE9; text-align: center; font-size: 16pt; color: #00A972;">&#10003;</td>
#     </tr>
#   </tbody>
# </table>
#
# </div>
#
# <!-- ===== CLOSING CALLOUT ===== -->
# <div style="margin-top: 20px; padding: 20px 28px; background: #FFF6F4; border: 3px solid #FF5F46; border-radius: 10px; text-align: center;">
#   <div style="font-size: 17pt; font-weight: 700; color: #FF5F46; margin-bottom: 8px;">Performance optimization is not a one-time task.</div>
#   <div style="font-size: 15pt; color: #0b2026; line-height: 1.6;">The best-performing workloads are maintained through continuous monitoring. Use the Spark UI to diagnose bottlenecks, apply targeted optimizations, validate improvements with metrics, and repeat as data volumes and query patterns evolve.</div>
# </div>
#
# </div>
#
#
# ##### EXPAND FOR ADDITIONAL NOTES
#
# <details>
#
# #### The Complete Optimization Toolkit
#
# This visual shows the three pillars of performance optimization you explored across all demos and labs. Each builds on the others to deliver fast, efficient workloads.
#
# #### Data Layout
#
# How your data is physically organized on disk has a direct impact on query speed. You learned that:
#
# - **Over-partitioning** creates thousands of small files, leading to excessive cloud storage requests and slow queries. Letting Spark handle file layout avoids this problem entirely.
# - **ZORDER** colocates related data in the same files, enabling data skipping for filtered queries — but only on the Z-ordered column.
# - **Liquid Clustering** replaces both partitioning and ZORDER with a flexible, multi-column approach. It supports redefining clustering keys without rewriting data and delivers strong file pruning across multiple query patterns.
#
# #### Query Execution
#
# Even with good data layout, query execution strategy matters:
#
# - **Shuffle joins** redistribute data across nodes, which is expensive for large tables. **Broadcast joins** send small tables to all nodes, avoiding the shuffle entirely.
# - **Exploding joins** caused by duplicate keys can multiply row counts by 100x, causing massive spill to disk. Reordering joins (smaller first) and using `ANALYZE TABLE` to enable the cost-based optimizer can eliminate spill.
# - **Python UDFs** bypass Spark's optimizer and process data serially by default. SQL UDFs are optimized by Catalyst and Photon. When Python UDFs are necessary, repartitioning enables parallel execution.
#
# #### Diagnose & Optimize
#
# The Spark UI is your primary diagnostic tool. Throughout this course you learned to read:
#
# - **Cloud storage request counts** and **response sizes** to understand I/O efficiency
# - **Files read** and **files pruned** to verify data skipping effectiveness
# - **Shuffle read/write sizes** to identify expensive data movement
# - **Disk spill metrics** to detect memory pressure
# - **Query plans (DAGs)** to trace the full execution path and verify optimization effects
#
# </details>

# %% [markdown]
# ## Predictive Optimization
#
# <br></br>
# <div style="max-width: 1200px; margin: 0 auto; font-family: sans-serif;">
#
# <div style="background: #F9F7F4; border-radius: 10px; padding: 24px 28px; box-shadow: 0 2px 8px rgba(27,49,57,0.06); border-top: 6px solid #FF5F46;">
#
#   <div style="font-size: 18pt; font-weight: 700; color: #0b2026; margin-bottom: 14px;">Let Databricks Optimize for You Automatically</div>
#
#   <div style="font-size: 15pt; color: #0b2026; line-height: 1.7; margin-bottom: 16px;">
#     Now that you understand the fundamentals of performance optimization, from data layout and clustering to join strategies and UDF tuning, explore <strong>Predictive Optimization</strong> to automate many of these tasks.
#   </div>
#
#   <div style="font-size: 15pt; color: #0b2026; line-height: 1.7; margin-bottom: 18px;">
#     Predictive Optimization automatically identifies tables that would benefit from maintenance operations and runs them for you. It handles <code style="background: #EEEDE9; padding: 2px 6px; border-radius: 3px;">OPTIMIZE</code>, <code style="background: #EEEDE9; padding: 2px 6px; border-radius: 3px;">VACUUM</code>, and <code style="background: #EEEDE9; padding: 2px 6px; border-radius: 3px;">ANALYZE TABLE</code> based on your table's usage patterns, removing the need for manual maintenance scheduling.
#   </div>
#
#   <div style="display: flex; gap: 10px; margin-top: 12px;">
#     <a href="https://docs.databricks.com/aws/en/optimizations/predictive-optimization" target="_blank" style="display: inline-block; background: #1B5162; color: white; font-size: 15pt; font-weight: 700; padding: 10px 24px; border-radius: 8px; text-decoration: none;">
#       AWS &rarr;
#     </a>
#     <a href="https://learn.microsoft.com/en-us/azure/databricks/optimizations/predictive-optimization" target="_blank" style="display: inline-block; background: #1B5162; color: white; font-size: 15pt; font-weight: 700; padding: 10px 24px; border-radius: 8px; text-decoration: none;">
#       Azure &rarr;
#     </a>
#     <a href="https://docs.databricks.com/gcp/en/optimizations/predictive-optimization" target="_blank" style="display: inline-block; background: #1B5162; color: white; font-size: 15pt; font-weight: 700; padding: 10px 24px; border-radius: 8px; text-decoration: none;">
#       GCP &rarr;
#     </a>
#   </div>
#
# </div>
#
# </div>

# %% [markdown]
# ## A. Additional Resources
#
# Explore the following resources to learn more about Databricks performance optimization and stay up to date with the latest platform updates.
#
# ### A1. Documentation
#
# - Optimization recommendations on Databricks:
# [AWS](https://docs.databricks.com/aws/en/optimizations/) |
# [Azure](https://learn.microsoft.com/en-us/azure/databricks/optimizations/) |
# [GCP](https://docs.databricks.com/gcp/en/optimizations/)
#
# - Partitioning recommendations - When and how to use partitioning:
# [AWS](https://docs.databricks.com/aws/en/tables/partitions) |
# [Azure](https://learn.microsoft.com/en-us/azure/databricks/tables/partitions) |
# [GCP](https://docs.databricks.com/gcp/en/tables/partitions)
#
# - Use liquid clustering for tables - Replaces table partitioning and ZORDER:
# [AWS](https://docs.databricks.com/aws/en/delta/clustering) |
# [Azure](https://learn.microsoft.com/en-us/azure/databricks/delta/clustering) |
# [GCP](https://docs.databricks.com/gcp/en/delta/clustering)
#
# - Data skipping with Z-order indexes for Delta Lake:
# [AWS](https://docs.databricks.com/aws/en/delta/data-skipping) |
# [Azure](https://learn.microsoft.com/en-us/azure/databricks/delta/data-skipping) |
# [GCP](https://docs.databricks.com/gcp/en/delta/data-skipping)
#
# - Optimize performance with caching on Databricks:
# [AWS](https://docs.databricks.com/aws/en/optimizations/disk-cache) |
# [Azure](https://learn.microsoft.com/en-us/azure/databricks/optimizations/disk-cache) |
# [GCP](https://docs.databricks.com/gcp/en/optimizations/disk-cache)
#
# ### A2. Blog and Announcements
#
# - [Announcing Automatic Liquid Clustering: Optimized data layout for up to 10x faster queries](https://www.databricks.com/blog/announcing-automatic-liquid-clustering) - Automatic Liquid Clustering eliminates the need to manually select clustering keys by analyzing query patterns and optimizing data layout automatically.
#
# - [Arrow-optimized Python UDFs in Apache Spark 3.5](https://www.databricks.com/blog/arrow-optimized-python-udfs-apache-sparktm-35) - How Arrow-optimized UDFs improve the efficiency of data exchange between the Spark runtime and the UDF process.
#
# - [Top 5 Performance Tips](https://www.databricks.com/blog/2022/03/10/top-5-databricks-performance-tips.html) - Practical tips for optimizing Spark workloads on Databricks.
#
# - [Accelerate Feature Engineering With Photon](https://www.databricks.com/blog/accelerate-feature-engineering-photon) - Learn how the Photon Engine in Databricks Machine Learning Runtime speeds up Spark jobs and feature engineering workloads by 2x or more.
#
# ### A3. Additional Features Outside the Scope of this Course
#
# - Predictive optimization for Unity Catalog managed tables:
# [AWS](https://docs.databricks.com/aws/en/optimizations/predictive-optimization) |
# [Azure](https://learn.microsoft.com/en-us/azure/databricks/optimizations/predictive-optimization) |
# [GCP](https://docs.databricks.com/gcp/en/optimizations/predictive-optimization)
#
# - Adaptive Query Execution:
# [Apache Spark AQE Documentation](https://spark.apache.org/docs/latest/sql-performance-tuning.html#adaptive-query-execution)
#
# - ANALYZE TABLE for statistics:
# [AWS](https://docs.databricks.com/aws/en/sql/language-manual/sql-ref-syntax-aux-analyze-table) |
# [Azure](https://learn.microsoft.com/en-us/azure/databricks/sql/language-manual/sql-ref-syntax-aux-analyze-table) |
# [GCP](https://docs.databricks.com/gcp/en/sql/language-manual/sql-ref-syntax-aux-analyze-table)
#
# - Photon runtime:
# [AWS](https://docs.databricks.com/aws/en/compute/photon) |
# [Azure](https://learn.microsoft.com/en-us/azure/databricks/compute/photon) |
# [GCP](https://docs.databricks.com/gcp/en/compute/photon)

# %% [markdown]
# ## B. Next Steps
#
# Continue building your Databricks skills with additional training and certification resources.
#
# ### B1. Continue Your Learning
#
# Expand your data and AI knowledge through Databricks self-paced and instructor-led training. These courses help you deepen your technical skills and gain hands-on experience with the Databricks platform.
#
# Visit the [Databricks Training and Certification](https://www.databricks.com/learn/training/home)
#
# - [Advanced Data Engineering with Databricks](https://www.databricks.com/training/catalog/advanced-data-engineering-with-databricks-971) - Build production data pipelines at scale with Delta Lake and Structured Streaming.
#
# - [Data Engineering with Databricks](https://www.databricks.com/learn/partners/partner-courses-and-public-schedule/data-engineering-databricks) - Learn the fundamentals of data engineering on the Databricks Lakehouse Platform.
#
# - [Apache Spark Programming with Databricks](https://www.databricks.com/training/catalog/apache-spark-programming-with-databricks-134) - Develop proficiency in using Apache Spark on the Databricks platform.
#
# ### B2. Earn a Certification
#
# Validate your Databricks expertise by earning an official credential. Certifications demonstrate your ability to apply Databricks technologies in real-world data and AI workloads.
#
# Visit the [Databricks Certification and Badging](https://www.databricks.com/learn/training/certification)

# %% [markdown]
# &copy; 2026 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
